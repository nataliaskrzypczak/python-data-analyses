# %% [markdown]
# # Statystyki wyścigowe w Formule 1
#
#
# **Conspect:**
# - Cel: Project showing basic F1 statistics and allows the user to enter data and process it.
# - Cel aplikacji: Aplikacja pozwala na wyświetlenie danych dotyczących wyścigów Formuły 1 dla podanych parametrów
# - <a href="https://www.kaggle.com/datasets/rohanrao/formula-1-world-championship-1950-2020">Kaggle dataset</a>

# %% [markdown]
# **Data Description**
#
# The data used for this project is a dataset on *Formula 1 World Championship from 1950 to 2020*, which was obtained from *Kaggle*.
# The dataset includes information on every race, driver, results and the circuits.
#
# **Project Description**
#
# The goal of this project is to create a program that displays basic Formula 1 statistics and allows the user to enter and process data.
# To achieve this, we will be using the previously mentioned *Formula 1 World Championship* dataset from *Kaggle*.
# The program will allow the user to view statistics such as driver and team standings, race winners or lap records.
# Additionally, the program will allow the user to enter their own data, such as lap times and race results, and process it to generate customized statistics and insights.
#
# ***This program can be useful for Formula 1 enthusiasts who want to explore and analyze the sport's data in an interactive way.***

# %% [markdown]
# # Import potrzebnych bibliotek

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Wczytanie plików

# %%
# ścieżka do folderu z plikami CSV
#data_path = r'C:\Users\natal\Desktop\my projects\Formula 1'

# %%
files = ['circuits.csv','drivers.csv', 'driver_standings.csv', 'races.csv', 'results.csv', 'status.csv']

data_frames = []

for file in files:
    data_frames.append(pd.read_csv(file))

merged_df = pd.concat(data_frames, ignore_index=True) # łączenie ramek

merged_df = merged_df[merged_df['year'] >= 1990] # ograniczenie wyników do roku 1990 wzwyż

merged_df
# Out:
#        circuitId circuitRef                      name location country  lat  \
# 34836        1.0        NaN     Australian Grand Prix      NaN     NaN  NaN
# 34837        2.0        NaN      Malaysian Grand Prix      NaN     NaN  NaN
# 34838       17.0        NaN        Chinese Grand Prix      NaN     NaN  NaN
# 34839        3.0        NaN        Bahrain Grand Prix      NaN     NaN  NaN
# 34840        4.0        NaN        Spanish Grand Prix      NaN     NaN  NaN
# ...          ...        ...                       ...      ...     ...  ...
# 35933       69.0        NaN  United States Grand Prix      NaN     NaN  NaN
# 35934       32.0        NaN    Mexico City Grand Prix      NaN     NaN  NaN
# 35935       18.0        NaN      São Paulo Grand Prix      NaN     NaN  NaN
# 35936       80.0        NaN      Las Vegas Grand Prix      NaN     NaN  NaN
# 35937       24.0        NaN      Abu Dhabi Grand Prix      NaN     NaN  NaN
#
# ...

# %%
# lista plików w folderze z danymi
files = os.listdir(data_path)

# iteracja po każdym pliku, łączenie i czyszczenie danych
dfs = []
for file in files:
    if file.endswith('.csv'): # tylko pliki CSV
        df = pd.read_csv(os.path.join(data_path, file))
        dfs.append(df)
merged_df = pd.concat(dfs, ignore_index=True)
merged_df.drop_duplicates(inplace=True) # usuwanie duplikatów
merged_df.dropna(inplace=True) # usuwanie brakujących wartości
merged_df.drop(columns=['url', 'location', 'circuitRef', 'country', 'lat', 'lng', 'alt', 'code', 'time',
       'fastestLap', 'rank', 'fastestLapTime', 'fastestLapSpeed' ], inplace=True) # usuwanie niepotrzebnych kolumn

# %%
merged_df.columns
# Out:
# Index(['circuitId', 'name', 'driverId', 'driverRef', 'number', 'forename',
#        'surname', 'dob', 'nationality', 'driverStandingsId', 'raceId',
#        'points', 'position', 'positionText', 'wins', 'year', 'round', 'date',
#        'fp1_date', 'fp1_time', 'fp2_date', 'fp2_time', 'fp3_date', 'fp3_time',
#        'quali_date', 'quali_time', 'sprint_date', 'sprint_time', 'resultId',
#        'constructorId', 'grid', 'positionOrder', 'laps', 'milliseconds',
#        'statusId', 'status'],
#       dtype='object')

# %%
output_file = os.path.join(data, 'cleaned_data.csv') # zapisanie zmodyfikowanej ramki do pliku
merged_df.to_csv(output_file, index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8776\1475624760.py in <module>
#       1 output_file = os.path.join(data, 'cleaned_data.csv') # zapisanie zmodyfikowanej ramki do pliku
# ----> 2 merged_df.to_csv(output_file, index=False)
#
# AttributeError: 'str' object has no attribute 'to_csv'

# %%
df.columns

# %% [markdown]
# # Czyszczenie danych

# %%
# lista plików w folderze z danymi
files = os.listdir(data)

# iteracja po każdym pliku i czyszczenie danych
for file in files:
    if file.endswith('.csv'): # tylko pliki CSV
        df = pd.read_csv(os.path.join(data, file))
        
        df.drop_duplicates(inplace=True) # usuwanie duplikatów
        df.dropna(inplace=True) # usuwanie brakujących wartości
        df.drop(columns=['url'], inplace=True) # usuwanie kolumny z linkami do wikipedii

        output_file = os.path.join(data, 'cleaned_' + file)  # zapisanie zmodyfikowanej ramki do pliku
        df.to_csv(output_file, index=False)

# %% [markdown]
# # EDA - podstawowe statystyki

# %%
cleaned_races.describe()

# %%
# ścieżka do folderu z plikami CSV
data = r'C:\Users\natal\Desktop\my projects\Formula 1'

# %%
cleaned_circuits.isna().sum()

# %%
# wizualizacja rozkładu kolumny 'lat'
sns.histplot(drivers['nationality'], kde=True)
plt.show()

# wyświetlenie macierzy korelacji między zmiennymi
sns.heatmap(drivers.corr(), annot=True, cmap='coolwarm')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_312\3079173919.py in <module>
#       1 # wizualizacja rozkładu kolumny 'lat'
# ----> 2 sns.histplot(drivers['nationality'], kde=True)
#       3 plt.show()
#       4
#       5 # wyświetlenie macierzy korelacji między zmiennymi
#
# NameError: name 'drivers' is not defined

# %%
 
        # wyświetlenie macierzy korelacji między zmiennymi
        sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
        plt.show()
        
        # wizualizacja rozkładu wybranej zmiennej
        sns.histplot(df['nazwa_kolumny'], kde=True)
        plt.show()
